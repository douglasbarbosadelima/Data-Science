# %% [markdown]
# <a href="https://colab.research.google.com/github/douglasbarbosadelima/Data-Science/blob/master/mega_sena_historical_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd

import pandas as pd
import numpy as np

# !ls -la # Access to Machine's CLI.

sena_file = pd.read_excel('./sample_data/mega_sena_historical_base.xlsx')

sena_file = sena_file.iloc[::-1] # Reverse the dataset
sena_file.head()

model = Sequential()
model.add(Dense(10, input_dim=6, activation='relu'))
model.add(Dense(6, activation='relu'))

model.compile(loss='mse', optimizer='adam')

X_train = np.array(sena_file.iloc[:1500:2])
Y_train = np.array(sena_file.iloc[1:1500:2])

X_test = np.array(sena_file[1500:2590].iloc[::2])
Y_test = np.array(sena_file[1500:2590].iloc[1::2])

print('X_train len: ', len(X_train))
print('Y_train len: ', len(Y_train))
print('X_test len: ', len(X_test))
print('Y_test len: ', len(Y_test))

model.fit(X_train, Y_train, epochs=1000, batch_size=32, validation_data=(X_test, Y_test))
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 May 11 16:35 .
# drwxr-xr-x 1 root root 4096 May 15 03:54 ..
# drwxr-xr-x 4 root root 4096 May 11 16:34 .config
# drwxr-xr-x 1 root root 4096 May 15 03:54 sample_data
# X_train len:  750
# Y_train len:  750
# X_test len:  545
# Y_test len:  545
# Epoch 1/1000
# 24/24 [==============================] - 1s 12ms/step - loss: 828.2974 - val_loss: 757.6624
# Epoch 2/1000
# 24/24 [==============================] - 0s 5ms/step - loss: 744.5878 - val_loss: 713.4848
# Epoch 3/1000
# 24/24 [==============================] - 0s 6ms/step - loss: 720.2578 - val_loss: 707.6683
# Epoch 4/1000
# 24/24 [==============================] - 0s 5ms/step - loss: 717.7145 - val_loss: 707.0613
# Epoch 5/1000
# 24/24 [==============================] - 0s 5ms/step - loss: 717.0609 - val_loss: 706.3660
# Epoch 6/1000
# 24/24 [==============================] - 0s 8ms/step - loss: 716.2589 - val_loss: 705.7730
# Epoch 7/1000
# ...

# %%
predictions = model.predict([[5, 9, 14, 30, 38, 50]])
predictions = map(lambda x: abs(x), predictions)
list(predictions)
# Out:
# 1/1 [==============================] - 0s 92ms/step
# [array([ 7.5279036, 14.810484 ,  0.       , 33.79993  , 41.817337 ,
#          0.       ], dtype=float32)]
